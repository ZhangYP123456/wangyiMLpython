# %% [markdown]
# % 是执行命令
# %% 是执行单元命令

# %%
# %magic

# %%
# %matplotlib inline
import pylab as pl
pl.seed(1)
data=pl.randn(100)
pl.plot(data)

# %%
# %config InlineBackend.figure_format="svg"
##
pl.plot(data)

# %% [markdown]
# matplotlib 是绘图扩展库
#
# %comfig 可以修改IPython中的各配置对象   InlineBackend 内嵌表格所使用的配置   figure_format="svg"表示图表输出格式是SVG
#
# 可以将图片输出模式修改成使用GUI界面库：gtk,osx,qt,qt4,tk,wk

# %% [markdown]
# %matplotlib qt4
# pl.plot(data)

# %%
# %%timeit
a=[]
for i in range(1,10):
    a.append(i)
# Out:
# 875 ns ± 2.16 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# %%timeit:执行多次代码
#
# %%time：执行一次代码    加上-o则返回一个运行时间信息的对象
#
# %%capture:将单元格的输出保存为一个对像
#
# %%prun:对单元格中的代码进行性能分析

# %%
# %%capture time_results
import random
for n in [501,1010,1510,20110,45110,641111]:
    print("n={0}".format(n))
    alist=list(range(n)) #range(),返回的是数组，不是列表
    # %time random.shuffle(alist)

# %%
print(time_results.stdout)
# Out:
# n=501
# Wall time: 1e+03 us
# n=1010
# Wall time: 2 ms
# n=1510
# Wall time: 4 ms
# n=20110
# Wall time: 23 ms
# n=45110
# Wall time: 32 ms
# n=641111
# Wall time: 483 ms

# %% [markdown]
# 代码调试debug
#
# 1,执行代码设置断点进行调试
# 2，代码抛出异常之后，执行命令查看调用堆栈
#
# %%func_bug

# %%
import math
def sinc(x):
    return math.sin(x)/x
[sinc(x) for x in range(5)]
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-12-ef7e2e79c2e6> in <module>()
#       2 def sinc(x):
#       3     return math.sin(x)/x
# ----> 4 [sinc(x) for x in range(5)]
#
# <ipython-input-12-ef7e2e79c2e6> in <listcomp>(.0)
#       2 def sinc(x):
#       3     return math.sin(x)/x
# ----> 4 [sinc(x) for x in range(5)]
#
# <ipython-input-12-ef7e2e79c2e6> in sinc(x)
#       1 import math
#       2 def sinc(x):
# ----> 3     return math.sin(x)/x
#       4 [sinc(x) for x in range(5)]
#
# ZeroDivisionError: float division by zero

# %%
# %debug              #利用命令px 显示变量x的值
# Out:
# > <ipython-input-12-ef7e2e79c2e6>(3)sinc()
#       1 import math
#       2 def sinc(x):
# ----> 3     return math.sin(x)/x
#       4 [sinc(x) for x in range(5)]
#
# ipdb> p x
# 0
# ipdb> q

# %% [markdown]
# %display模块
